# %%
# Create RO Crates from BioDT B2Share records
#
# written for the BioDT project https://doi.org/10.3030/101057437
# Oct 2024

# !pip install rocrate
# !pip install deims

from rocrate.rocrate import ROCrate # tested with rocrate 0.10.0
from rocrate.model.contextentity import ContextEntity
import json
import deims
from urllib.request import urlopen

crate = ROCrate()

# provide general information about the model
model = crate.add(ContextEntity(crate, "grassmind", properties={
    "@type": ["File", "SoftwareSourceCode", "ComputationalWorkflow"],
    "name": "GRASSMIND",
    "url": "https://www.ufz.de/index.php?en=48445",
    "version": "2.0",
    "programmingLanguage": {"@id": "#c++"},
    "creator": [
        {"@id": "#https://orcid.org/0000-0001-8541-789X"},
        {"@id": "#https://orcid.org/0000-0001-7594-8152"},
    ],
    "dateCreated": "2024-07-10",
    "license": {"@id": "tbd"},
    "input": []
}))

model_creator1 = crate.add(ContextEntity(crate, "Thomas Banitz", properties={
    "@id": "https://orcid.org/0000-0001-8541-789X",
    "creator_name": "Thomas Banitz",
    "family_name": "Banitz",
    "given_name": "Thomas"
}))

model_creator2 = crate.add(ContextEntity(crate, "Franziska Taubert", properties={
    "@id": "https://orcid.org/0000-0001-7594-8152",
    "creator_name": "Franziska Taubert",
    "family_name": "Taubert",
    "given_name": "Franziska"
}))

# query B2Share API for LTER, BioDT and Grassland records
url = "https://b2share.eudat.eu/api/records/?q=keywords.keyword=%27BioDT%20AND%20Grassland%20pDT%27&community=d952913c-451e-4b5c-817e-d578dc8a4469&size=100"
response = urlopen(url)
json_response = json.loads(response.read())
list_of_file_ids = []

for record in json_response['hits']['hits']:

    # deims.id can be used to get any information about site from DEIMS
    deims_id = record["metadata"]["community_specific"]["d2f5457f-6318-494a-b363-8098356035b7"]["metadata_url"]

    list_of_keyword_labels = []
    for keyword in record["metadata"]["keywords"]:
        list_of_keyword_labels.append(keyword["keyword"])

    list_of_related_files = []

    creators = []
    for creator in record["metadata"]["creators"]:
        creator_object = {
            "@id": creator["creator_name"],
            "creator_name": creator["creator_name"],
            "family_name": creator["family_name"],
            "given_name": creator["given_name"]
        }
        creators.append(creator_object)

    deims_site_record = deims.getSiteById(deims_id)

    current_crate = crate.add(ContextEntity(crate, "dataset", properties={
        "name": record["metadata"]["titles"][0]["title"],
        "@id": record["metadata"]["DOI"],
        "description": record["metadata"]["descriptions"][0]["description"],
        "keywords": list_of_keyword_labels,
        "dateCreated": record["created"],
        "variableMeasured": "Grassland Dynamics",
        "spatialCoverage": {
            "@id": deims_id
        },
        "creators": creators,
        "license": record["metadata"]["license"]["license"],
        "hasPart": list_of_related_files
    }))

    list_of_file_ids.append(record["metadata"]["DOI"])

    eLTER = crate.add(ContextEntity(crate, "https://elter-ri.eu/", properties={
        "@type": "Organization",
        "name": "eLTER",
        "url": "https://elter-ri.eu/",
    }))
    current_crate.append_to("organization", eLTER)

    deims_site_record["attributes"]["geographic"]

    coordinates = deims_site_record["attributes"]["geographic"]["coordinates"]
    coordinates = coordinates.split("(")[1].split(")")[0].split(" ")

    place = crate.add(ContextEntity(crate, deims_id, properties={
        "@type": "Place",
        "name": deims_site_record["attributes"]["general"]["siteName"],
        "description": deims_site_record["attributes"]["general"]["abstract"],
        "geo": {
            "@type": "GeoCoordinates",
            "@id": deims_id,
            "lat": coordinates[1],
            "lon": coordinates[0],
        }
    }))
    current_crate.append_to("Place", place)

    for file in record['files']:
        list_of_related_files.append(file['ePIC_PID'])
        current_file = crate.add_file(file['ePIC_PID'], properties={
            "name": file['key'],
            "contentSize": str(file['size']),
        })

    current_crate.append_to("file", current_file)

model["input"] = list_of_file_ids

crate.write("grassland_crate")
# Out:
# Requirement already satisfied: rocrate in /opt/conda/lib/python3.11/site-packages (0.11.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from rocrate) (2.31.0)
# Requirement already satisfied: arcp==0.2.1 in /opt/conda/lib/python3.11/site-packages (from rocrate) (0.2.1)
# Requirement already satisfied: galaxy2cwl in /opt/conda/lib/python3.11/site-packages (from rocrate) (0.1.4)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from rocrate) (3.1.2)
# Requirement already satisfied: python-dateutil in /opt/conda/lib/python3.11/site-packages (from rocrate) (2.8.2)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from rocrate) (8.1.7)
# Requirement already satisfied: pyyaml>=5.3.0 in /opt/conda/lib/python3.11/site-packages (from galaxy2cwl->rocrate) (6.0.1)
# Requirement already satisfied: gxformat2>=0.11.0 in /opt/conda/lib/python3.11/site-packages (from galaxy2cwl->rocrate) (0.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->rocrate) (2.1.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil->rocrate) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->rocrate) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->rocrate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->rocrate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->rocrate) (2023.11.17)
# Requirement already satisfied: bioblend in /opt/conda/lib/python3.11/site-packages (from gxformat2>=0.11.0->galaxy2cwl->rocrate) (1.3.0)
# Requirement already satisfied: schema-salad>=8.2 in /opt/conda/lib/python3.11/site-packages (from gxformat2>=0.11.0->galaxy2cwl->rocrate) (8.7.20241021092521)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.11/site-packages (from gxformat2>=0.11.0->galaxy2cwl->rocrate) (4.8.0)
# Requirement already satisfied: ruamel.yaml<0.19,>=0.17.6 in /opt/conda/lib/python3.11/site-packages (from schema-salad>=8.2->gxformat2>=0.11.0->galaxy2cwl->rocrate) (0.17.39)
# Requirement already satisfied: rdflib<8.0.0,>=4.2.2 in /opt/conda/lib/python3.11/site-packages (from schema-salad>=8.2->gxformat2>=0.11.0->galaxy2cwl->rocrate) (7.1.0)
# Requirement already satisfied: mistune<3.1,>=3 in /opt/conda/lib/python3.11/site-packages (from schema-salad>=8.2->gxformat2>=0.11.0->galaxy2cwl->rocrate) (3.0.1)
# Requirement already satisfied: CacheControl<0.15,>=0.13.1 in /opt/conda/lib/python3.11/site-packages (from CacheControl[filecache]<0.15,>=0.13.1->schema-salad>=8.2->gxformat2>=0.11.0->galaxy2cwl->rocrate) (0.14.0)
# Requirement already satisfied: mypy-extensions in /opt/conda/lib/python3.11/site-packages (from schema-salad>=8.2->gxformat2>=0.11.0->galaxy2cwl->rocrate) (1.0.0)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.5.1 in /opt/conda/lib/python3.11/site-packages (from bioblend->gxformat2>=0.11.0->galaxy2cwl->rocrate) (1.0.0)
# Requirement already satisfied: tuspy in /opt/conda/lib/python3.11/site-packages (from bioblend->gxformat2>=0.11.0->galaxy2cwl->rocrate) (1.0.3)
# Requirement already satisfied: msgpack<2.0.0,>=0.5.2 in /opt/conda/lib/python3.11/site-packages (from CacheControl<0.15,>=0.13.1->CacheControl[filecache]<0.15,>=0.13.1->schema-salad>=8.2->gxformat2>=0.11.0->galaxy2cwl->rocrate) (1.0.6)
# Requirement already satisfied: filelock>=3.8.0 in /opt/conda/lib/python3.11/site-packages (from CacheControl[filecache]<0.15,>=0.13.1->schema-salad>=8.2->gxformat2>=0.11.0->galaxy2cwl->rocrate) (3.16.1)
# Requirement already satisfied: html5lib-modern<2.0,>=1.2 in /opt/conda/lib/python3.11/site-packages (from rdflib<8.0.0,>=4.2.2->schema-salad>=8.2->gxformat2>=0.11.0->galaxy2cwl->rocrate) (1.2)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from rdflib<8.0.0,>=4.2.2->schema-salad>=8.2->gxformat2>=0.11.0->galaxy2cwl->rocrate) (3.1.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/conda/lib/python3.11/site-packages (from ruamel.yaml<0.19,>=0.17.6->schema-salad>=8.2->gxformat2>=0.11.0->galaxy2cwl->rocrate) (0.2.7)
# Requirement already satisfied: tinydb>=3.5.0 in /opt/conda/lib/python3.11/site-packages (from tuspy->bioblend->gxformat2>=0.11.0->galaxy2cwl->rocrate) (4.8.2)
# Requirement already satisfied: aiohttp>=3.6.2 in /opt/conda/lib/python3.11/site-packages (from tuspy->bioblend->gxformat2>=0.11.0->galaxy2cwl->rocrate) (3.8.6)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.6.2->tuspy->bioblend->gxformat2>=0.11.0->galaxy2cwl->rocrate) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.6.2->tuspy->bioblend->gxformat2>=0.11.0->galaxy2cwl->rocrate) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.6.2->tuspy->bioblend->gxformat2>=0.11.0->galaxy2cwl->rocrate) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.6.2->tuspy->bioblend->gxformat2>=0.11.0->galaxy2cwl->rocrate) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.6.2->tuspy->bioblend->gxformat2>=0.11.0->galaxy2cwl->rocrate) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp>=3.6.2->tuspy->bioblend->gxformat2>=0.11.0->galaxy2cwl->rocrate) (1.3.1)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: deims in /opt/conda/lib/python3.11/site-packages (4.0)
# Requirement already satisfied: geopandas in /opt/conda/lib/python3.11/site-packages (from deims) (0.14.2)
# Requirement already satisfied: geopy in /opt/conda/lib/python3.11/site-packages (from deims) (2.4.1)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (from deims) (2.1.1)
# Requirement already satisfied: fiona>=1.8.21 in /opt/conda/lib/python3.11/site-packages (from geopandas->deims) (1.9.5)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from geopandas->deims) (23.2)
# Requirement already satisfied: pyproj>=3.3.0 in /opt/conda/lib/python3.11/site-packages (from geopandas->deims) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /opt/conda/lib/python3.11/site-packages (from geopandas->deims) (2.0.2)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas->deims) (1.24.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->deims) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->deims) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas->deims) (2023.3)
# Requirement already satisfied: geographiclib<3,>=1.52 in /opt/conda/lib/python3.11/site-packages (from geopy->deims) (2.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas->deims) (23.1.0)
# Requirement already satisfied: click~=8.0 in /opt/conda/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas->deims) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /opt/conda/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas->deims) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /opt/conda/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas->deims) (0.7.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas->deims) (1.16.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from fiona>=1.8.21->geopandas->deims) (68.2.2)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.11/site-packages (from pyproj>=3.3.0->geopandas->deims) (2023.11.17)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# visualsierung
